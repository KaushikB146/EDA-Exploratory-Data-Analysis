# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('insurance.csv')
data.shape
# Out:
# (1338, 7)

# %%
data.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 956    54    male  30.800         1    yes  southeast  41999.52000
# 429    27  female  30.400         3     no  northwest  18804.75240
# 497    45    male  28.700         2     no  southwest   8027.96800
# 225    55    male  33.880         3     no  southeast  11987.16820
# 240    23  female  36.670         2    yes  northeast  38511.62830
# 734    59  female  32.100         3     no  southwest  14007.22200
# 1210   36    male  30.875         1     no  northwest   5373.36425
# 587    34  female  30.210         1    yes  northwest  43943.87610
# 296    19    male  27.700         0    yes  southwest  16297.84600
# 1209   59    male  37.100         1     no  southwest  12347.17200

# %%
data.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
# decsribing the data

data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# information about the data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
data["Mean"] = ((data["age"] + data["bmi"] + data["charges"]) / 3 ).round()
data.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges    Mean
# 0   19  female  27.900         0    yes  southwest  16884.92400  5644.0
# 1   18    male  33.770         1     no  southeast   1725.55230   592.0
# 2   28    male  33.000         3     no  southeast   4449.46200  1503.0
# 3   33    male  22.705         0     no  northwest  21984.47061  7347.0
# 4   32    male  28.880         0     no  northwest   3866.85520  1309.0
# 5   31  female  25.740         0     no  southeast   3756.62160  1271.0
# 6   46  female  33.440         1     no  southeast   8240.58960  2773.0
# 7   37  female  27.740         3     no  northwest   7281.50560  2449.0
# 8   37    male  29.830         2     no  northeast   6406.41070  2158.0
# 9   60  female  25.840         0     no  northwest  28923.13692  9670.0

# %%
# checking the datatypes of attributes of dataset

data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# Mean        float64
# dtype: object

# %%
# checking if there is any NULL values present in the dataset

data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# Mean        0
# dtype: int64

# %%
data['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
# pie chart 

size = [676, 662]
labels = ['Male', 'Female']
colors = ['blue', 'green']
explode = [0, 0.1]

plt.pie(size, colors = colors, labels = labels, shadow = True, explode = explode, autopct = '%.2f%%')
plt.title('A Pie Chart representing the gender gap', fontsize = 20)
plt.legend()
plt.show()

# %%
# visualizing the age of customers

sns.countplot(data['age'], palette = 'pastel')
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Different Categories of Age', fontsize = 20)
plt.ylabel('Count')
plt.show()

# %%
# visualizing the charges of customers

sns.countplot(data['charges'], palette = 'pastel')
plt.title('Distribution of Occupation across customers', fontsize = 20)
plt.xlabel('charges')
plt.ylabel('Count')
plt.show()

# %%
# visulaizing the region the customers are from

sns.countplot(data['region'], palette = 'colorblind')
plt.title('Distribution of Cities across customers', fontsize = 20)
plt.xlabel('region')
plt.ylabel('Count')
plt.show()

# %%
## plotting different columns in Histogram:
data.hist(bins=30,figsize=(20,20),color= 'g')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.heatmap(data.corr(),annot=True,cmap='summer')
plt.title("Heatmap of the dataset")
plt.show()

# %%
# visualizing smoker customers

sns.countplot(data['smoker'], palette = 'pastel')
plt.title('SMOKERS', fontsize = 20)
plt.xlabel('No. of smokers', fontsize = 20)
plt.ylabel('Count')
plt.show()

# %%
# visualizing the product category 1

plt.rcParams['figure.figsize'] = (15, 5)

plt.subplot(131)
sns.countplot(data['age'], palette = 'dark')
plt.title('Distribution of different age customers', fontsize = 20)
plt.xlabel('Distribution of Product Category 1')
plt.ylabel('Count')

plt.subplot(132)
sns.countplot(data['bmi'], palette = 'pastel')
#plt.title('Distribution of bmi across customers', fontsize = 20)
plt.xlabel('Distribution of Product Category 2')
plt.ylabel('Count')

plt.subplot(133)
sns.countplot(data['charges'], palette = 'dark')
#plt.title('Distribution of charges across customers', fontsize = 20)
plt.xlabel('Distribution of Product Category 3')
plt.ylabel('Count')


plt.show()

# %%
data[['age', 'bmi']].groupby('bmi').mean()
# Out:
#               age
# bmi
# 15.960  18.000000
# 16.815  29.500000
# 17.195  26.000000
# 17.290  27.666667
# 17.385  23.000000
# 17.400  21.000000
# 17.480  19.000000
# 17.670  26.000000
# 17.765  32.000000
# 17.800  19.000000
# 17.860  35.000000
# 17.955  27.000000
# 18.050  51.000000
# 18.300  39.000000
# 18.335  56.333333
# 18.500  33.000000
# 18.600  19.000000
# 18.715  23.000000
# 18.905  27.000000
# 19.000  34.000000
# 19.095  33.000000
# 19.190  47.000000
# 19.300  38.000000
# 19.475  38.000000
# 19.570  47.000000
# 19.800  28.333333
# 19.855  41.000000
# 19.950  38.333333
# 20.045  35.000000
# 20.100  57.000000
# ...           ...
# 43.010  18.000000
# 43.120  30.000000
# 43.340  35.000000
# 43.400  61.000000
# 43.700  57.000000
# 43.890  45.000000
# 44.000  61.000000
# 44.220  31.000000
# 44.700  52.000000
# 44.745  50.000000
# 44.770  50.000000
# 44.880  19.000000
# 45.320  47.000000
# 45.430  39.000000
# 45.540  25.000000
# 45.900  27.000000
# 46.090  50.000000
# ...
